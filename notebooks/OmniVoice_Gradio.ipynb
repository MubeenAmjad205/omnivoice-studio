# %% [markdown]
# <div align="center" style="font-family: Arial, sans-serif; background-color: #1e1e1e; padding: 30px; border-radius: 15px; color: white;">
#   <h1 style="color: #00e5ff; margin-bottom: 5px;">🎙️ OmniVoice Colab UI</h1>
#   <h3 style="margin-top: 0; font-weight: normal;">High-Quality Voice Cloning & Design for 600+ Languages</h3>
#   <p style="font-size: 14px; color: #aaaaaa;">Generate consistent, professional voiceovers with an easy-to-use Gradio interface.</p>
# </div>
#
# ---
# ### 🚀 **Quick Start Guide**
# 1. **Enable GPU:** Go to `Runtime > Change runtime type` in the top menu and select **T4 GPU**.
# 2. **Run Step 1:** Click the play button next to the Installation cell to download the model.
# 3. **Run Step 2:** Click play on the Launch cell. After a moment, a public **`xxxx.gradio.live`** link will appear in the output.
# 4. Click that link to open the OmniVoice app in a new, full-screen tab!

# %%
# @title 1️⃣ Install OmniVoice & Dependencies
from IPython.display import clear_output

print("Installing OmniVoice... (This will take a minute or two)")
# !pip install omnivoice gradio > /dev/null 2>&1

clear_output()
print("✅ Installation Successful! You can now run Step 2.")
# Out:
# ✅ Installation Successful! You can now run Step 2.

# %%
# @title 2️⃣ Launch the Gradio Web UI
# The '--share' flag automatically creates the public gradio.live link.
# !omnivoice-demo --share
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# 2026-04-08 04:35:26,132 root INFO: Loading model from k2-fsa/OmniVoice, device=cuda ...
# config.json: 2.24kB [00:00, 8.65MB/s]
# model.safetensors: 100% 2.45G/2.45G [00:17<00:00, 142MB/s]
# Loading weights: 100% 313/313 [00:01<00:00, 285.58it/s]
# ...
