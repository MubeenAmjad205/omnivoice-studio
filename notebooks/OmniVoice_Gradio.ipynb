# %% [markdown]
# <div align="center" style="font-family: Arial, sans-serif; background-color: #1e1e1e; padding: 30px; border-radius: 15px; color: white;">
#   <h1 style="color: #00e5ff; margin-bottom: 5px;">🎙️ OmniVoice Studio</h1>
#   <h3 style="margin-top: 0; font-weight: normal;">High-Quality Voice Cloning</h3>
#   <p style="font-size: 14px; color: #aaaaaa;">Generate consistent, professional voiceovers with an easy-to-use Gradio interface.</p>
# </div>
#
# ---
# ### 🚀 **Quick Start Guide**
# 1. **Enable GPU:** Go to `Runtime > Change runtime type` in the top menu and select **T4 GPU**.
# 2. **Add Token (Optional):** Click the 🔑 icon on the left to add a secret named `HF_TOKEN` with your Hugging Face token to speed up downloads.
# 3. **Run the Cell Below:** Click the play button to automatically install and launch the app.
# 4. A public **`xxxx.gradio.live`** link will appear at the bottom. Click it to open your UI!

# %%
# @title 🚀 Install and Run OmniVoice Studio
import os

repo_url = "https://github.com/MubeenAmjad205/omnivoice-studio.git"
repo_dir = "omnivoice-studio"

if not os.path.exists(repo_dir):
    print("1. Cloning Repository...")
    # !git clone {repo_url}

print("\n2. Entering project directory...")
os.chdir(repo_dir)

print("\n3. Installing Dependencies (this takes a minute)...")
# !pip install -r requirements.txt > /dev/null 2>&1
print("✅ Dependencies installed successfully!")

print("\n4. Checking for Hugging Face Token in Colab Secrets...")
try:
    from google.colab import userdata
    hf_token = userdata.get('HF_TOKEN')
    if hf_token:
        os.environ["HF_TOKEN"] = hf_token
        print("✅ HF_TOKEN found and loaded successfully! Downloads will be faster.")
    else:
        print("⚠️ HF_TOKEN is empty in Colab Secrets. Proceeding without it.")
except Exception as e:
    print("⚠️ HF_TOKEN not found in Colab Secrets. Proceeding without it (downloads may be slower).")

print("\n5. Launching OmniVoice Studio...")
# !python scripts/run_colab.py
